# %% [markdown]
# <a href="https://colab.research.google.com/github/blaQPablo88/Big-Data-Analytics-with-LLM/blob/main/dummy_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. CREATEING A DUMMY DATASET

# %%
pip install pandas numpy

# %%
import pandas as pd
import numpy as np
from random import choices

# %%
np.random.seed(10)

# %%
num_records = 1000
num_outlets = 10
num_products = 20

# %%
#2 quarters (jan-mar, apr-jun)
dates = pd.date_range(start='2023-01-01', end='2023-06-30')
dates = choices(dates, k=num_records)

# %%
outlets = ['Outlet_' + str(i + 1) for i in range(num_outlets)]
outlets = choices(outlets, k=num_records)

# %%
products = ['Products_' + str(i + 1) for i in range(num_products)]
products = choices(products, k=num_records)

# %%
units_sold = np.random.randint(1, 200, num_records)
price_per_unit = np.random.uniform(10, 500, num_records)

# %%
total_sales = units_sold * price_per_unit

# %%
df = pd.DataFrame({
  'Date': dates,
  'Outlet': outlets,
  'Product': products,
  'Unit_sold': units_sold,
  'Price_per_unit': price_per_unit,
  'Total_sales': total_sales
})

# %%
df
# Out:
#           Date
# 0   2023-06-27
# 1   2023-01-15
# 2   2023-06-18
# 3   2023-04-28
# 4   2023-02-05
# ..         ...
# 995 2023-03-05
# 996 2023-01-17
# 997 2023-05-15
# 998 2023-03-18
# 999 2023-05-10
#
# [1000 rows x 1 columns]
